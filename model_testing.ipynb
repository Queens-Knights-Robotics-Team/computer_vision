# %%
import os
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# %cd /content
# !pip install roboflow
from roboflow import Roboflow
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)
# /content
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
# ...

# %%
# import the gdrive library
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cebdf7998637> in <cell line: 3>()
#       1 # import the gdrive library
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Image(filename = f'/content/drive/MyDrive/QKRT/training_file/content/runs/detect/train4/confusion_matrix.png')

# %%
#Image(filename = f'/content/drive/MyDrive/QKRT/training_file/content/runs/detect/train4/results.png')

# %%
dataset = "/content/drive/MyDrive/QKRT/realsense-1"
# !yolo task=detect mode=val model=/content/drive/MyDrive/QKRT/training_file/content/runs/detect/train4/weights/best.pt data={dataset}/data.yaml

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/QKRT/training_file/content/runs/detect/train4/weights/best.pt conf=0.5 source={dataset}/test/images

# %%
# !yolo predict model=/content/drive/MyDrive/QKRT/training_file/content/runs/detect/train4/weights/best.pt conf=0.5 source='/content/drive/MyDrive/QKRT/our_pictures/RM_comp_pic2.jpg'
