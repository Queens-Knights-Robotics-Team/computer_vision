# %%
import os

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# %cd /content
# !pip install roboflow
from roboflow import Roboflow
# Out:
# /content
# ...

# %%
#downloads the the data set. already downloaded in google drive QKRT realsense-1 folder

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SFgaV6MyAYtjI0Ap4BVR")
project = rf.workspace("yin").project("realsense")
dataset = project.version(1).download("yolov8")
# Out:
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.232, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to realsense-1 in yolov8:: 100%|██████████| 8640/8640 [00:02<00:00, 3506.42it/s]

# %% [markdown]
# Model Training

# %%
# %cd {home}  <-- i removed this line

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/file.zip /content/runs
from google.colab import files
files.download("/content/file.zip")
# Out:
# 	zip warning: name not matched: /content/runs
#
# zip error: Nothing to do! (try: zip -r /content/file.zip . -i /content/runs)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6ca566dbcbc6> in <cell line: 3>()
#       1 get_ipython().system('zip -r /content/file.zip /content/runs')
#       2 from google.colab import files
# ----> 3 files.download("/content/file.zip")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/file.zip
